# %% [markdown]
# <a href="https://colab.research.google.com/github/frcaulia/PCVK_GANJIL_2023/blob/main/Week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %%
# create a list to store urls of multiple images
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/880,/0/default.jpg",
        "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
        "https://placekitten.com/888/571" ]

# read and display the image
# loops over each image url, multiple images can be stored in the list
for url in urls:
  image = io.imread(url) # read image
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5) # resize image to half size
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB) # convert color to RGB
  final_frame = cv.hconcat((image, image_2)) # concatenate image
  cv2_imshow(final_frame) # show image
  print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=880x304>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=888x286>

# %%
# create a list to store urls of multiple images
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
        "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
        "https://placekitten.com/800/624"]

# read and display the image
# loops over each image url, multiple images can be stored in the list
for url in urls:
  image = io.imread(url) # read image
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5) # resize image to half size
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB) # convert color to RGB
  final_frame = cv.hconcat((image, image_2)) # concatenate image
  cv2_imshow(final_frame) # show image
  print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=800x312>

# %%
height = image_2.shape[0]
width = image_2.shape[1]
print("image resolution: height x width = ", height, "x", width)
cv2_imshow(image_2)
# Out:
# image resolution: height x width =  290 x 400
# <PIL.Image.Image image mode=RGB size=400x290>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# draw a horizontal line in the middle of the image
for y in range(width):
  image_3[int((height)/2),y] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x290>

# %% [markdown]
# ##Question
# 1. Explain why in this practicum module the execution of Python code is done using
# Google Colab?
# 2. Explain the use of each library in the eighth step practicum? Do all these libraries have
# to be used in this practical session?
# 3. In the 8th step of the experiment there is a snippet of program code as follows: image = cv.resize(image, (0,0), fx=0.5, fy=0.5)
# 4. Take a look at the following program code snippet: # draw a horizontal line in the middle of the image
# for y in range(width):
#   image_3[int((height)/2),y] = [255, 255, 255]
#   What is the use of the code [255,255,255] ? Explain!
# 5. Explain the relationship between pixels and high or low image resolution!

# %% [markdown]
# ###Answer
# 1. anu
# 2. anu
# 3. anu
# 4. anu
# 5. anu
